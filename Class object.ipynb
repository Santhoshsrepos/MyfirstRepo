# %%
class goa:
    name="Santy"
    drink=""
    def party(self):
        print("Let's party...")
    def beach(self):
        print("ENjoy the beach")

ramesh=goa()
suresh=goa()

ramesh.name="ramesh"
print(ramesh.name)
# Out:
# ramesh
