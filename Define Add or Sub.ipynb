# %%
print("Addition: ")
def add():
    a=int(input("Enter a: "))
    b=int(input("Enter b: "))
    print("The sum of a+b is: ", a+b)
add()  

print("subraction: ")
def sub():
    a=int(input("Enter a: "))
    b=int(input("Enter b: "))
    print(a-b)
sub()
# Out:
# Addition:
# Enter a:  10
# Enter b:  20
# The sum of a+b is:  30
# subraction:
# Enter a:  10
# Enter b:  20
# -10
